# %% [markdown]
# # 📊 Praktikum Data Science - Pertemuan 1
#
# ## Pengenalan Data Science
#
# 👤 Nama : Deviani Solikhah
# 🆔 NIM : 240401010137
# 🏫 Kelas : IF403
# 💻 Program Studi : S1 PJJ Informatika
#
# ---
#
# ### 🎯 Tujuan Praktikum
#
# Praktikum ini bertujuan untuk memberikan pemahaman awal mengenai konsep dasar Data Science serta peranannya dalam pengolahan dan analisis data. Pada pertemuan ini, saya juga mempelajari penggunaan Google Colab dan GitHub sebagai tools pendukung pembelajaran, serta mencoba menjalankan program Python sederhana sebagai langkah awal dalam mempelajari Data Science.

# %%
# SEL 1: Output Sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
print()

# SEL 2: Variabel & Tipe Data
nama = "Deviani Solikhah"
angkatan = 2024
ipk = 4
aktif = True
print(f"Nama : {nama}")
print(f"Angkatan : {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
print()

# SEL 3: List & Perulangan 
tools = [
    "Python",
    "Google Colab",
    "Jupyter Notebook",
    "GitHub"
]
print("Tools Data Science yang akan dipelajari:")
for i, tool in enumerate(tools, start=1):
    print(f"{i}. {tool}")
print()

# SEL 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
    return f"{nama} | {prodi} | {angkatan}."
hasil = perkenalan(
    "Deviani Solikhah",
    "Informatika",
    2024
)
print(hasil)
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!
#
# Nama : Deviani Solikhah
# Angkatan : 2024
# IPK : 4
# Aktif : True
#
# Tools Data Science yang akan dipelajari:
# 1. Python
# 2. Google Colab
# 3. Jupyter Notebook
# 4. GitHub
#
# Deviani Solikhah | Informatika | 2024.

# %% [markdown]
# ## 📝 Kesimpulan
#
# Berdasarkan praktikum yang telah dilakukan, saya memperoleh pemahaman awal mengenai Data Science sebagai bidang yang memanfaatkan data untuk menghasilkan informasi yang dapat digunakan dalam pengambilan keputusan. Saya juga mengenal beberapa tools yang sering digunakan dalam Data Science, salah satunya GitHub sebagai media penyimpanan dan dokumentasi proyek.
#
# Selain itu, melalui latihan Python sederhana saya dapat memahami penggunaan variabel, tipe data, list, perulangan, dan fungsi dasar. Praktikum pada pertemuan pertama ini menjadi landasan penting untuk mempelajari materi Data Science yang lebih lanjut pada pertemuan berikutnya.
